# %%
# !pip install rdflib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rdflib in /home/aag-spike/.local/lib/python3.8/site-packages (7.0.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/aag-spike/.local/lib/python3.8/site-packages (from rdflib) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /home/aag-spike/.local/lib/python3.8/site-packages (from rdflib) (3.0.9)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.14.0)

# %%
# !pip install pyvis
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyvis
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: ipython>=5.3.0 in /usr/lib/python3/dist-packages (from pyvis) (7.13.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/lib/python3/dist-packages (from pyvis) (2.10.1)
# Collecting jsonpickle>=1.4.1 (from pyvis)
#   Downloading jsonpickle-3.0.3-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: networkx>=1.11 in /home/aag-spike/.local/lib/python3.8/site-packages (from pyvis) (3.1)
# Requirement already satisfied: pexpect in /home/aag-spike/.local/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (4.9.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/aag-spike/.local/lib/python3.8/site-packages (from pexpect->ipython>=5.3.0->pyvis) (0.7.0)
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 15.9 MB/s eta 0:00:00a 0:00:01
# Downloading jsonpickle-3.0.3-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: jsonpickle, pyvis
# Successfully installed jsonpickle-3.0.3 pyvis-0.3.2

# %%
import rdflib
from rdflib import Graph
import matplotlib.pyplot as plt
import networkx as nx

# Load the Turtle file into an RDFlib Graph
g = Graph()
g.parse("data/kg_ai.ttl", format="turtle")

# Convert the RDFlib Graph into a NetworkX graph for visualization
G = nx.DiGraph()

for subject, predicate, obj in g:
    
    # Simplify URIs for better readability in the visualization
    sub_label = subject.split('#')[-1]
    pred_label = predicate.split('#')[-1]
    obj_label = obj.split('#')[-1] if isinstance(obj, rdflib.term.URIRef) else str(obj)
    #print(f"{sub_label} -> {pred_label} -> {obj_label}")
    
    # Add nodes and edges to the NetworkX graph
    G.add_node(sub_label.replace('%20', ' '))
    if "embedding" not in pred_label:
        G.add_node(obj_label.replace('%20', ' '))
        G.add_edge(sub_label.replace('%20', ' '), obj_label.replace('%20', ' '), label=pred_label)

# Draw the graph
plt.figure(figsize=(16, 16))
pos = nx.spring_layout(G, k=2)  # Positions for all nodes

# Nodes
nx.draw_networkx_nodes(G, pos, node_size=7000, node_color="skyblue", alpha=0.6)

# Edges
nx.draw_networkx_edges(G, pos, width=2, alpha=0.5, edge_color="gray")

# Labels
nx.draw_networkx_labels(G, pos, font_size=10)

# Edge labels
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='green')

plt.title('Knowledge Graph Visualization', size=15)
plt.axis('off')
plt.show()
